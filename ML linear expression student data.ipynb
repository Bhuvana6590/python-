# %% [markdown]
# Inpendent variable input Hours
#
# dependannt variable Out put Marks

# %%
#Importing the Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the Dataset
student=pd.read_csv('Student data.csv')
student
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   30 non-null     int64
#  1   Marks   30 non-null     int64
# dtypes: int64(2)
# memory usage: 612.0 bytes

# %%
student.describe()
# Out:
#            Hours      Marks
# count  30.000000  30.000000
# mean    5.200000  61.400000
# std     3.188341  17.734828
# min     0.000000  33.000000
# 25%     3.000000  45.250000
# 50%     5.000000  60.000000
# 75%     7.750000  77.000000
# max    11.000000  89.000000

# %% [markdown]
# Segregate the dataset into independant Variable (x) and dependant variable (y)

# %%
x=student.iloc[:,:-1].values
y=student.iloc[:,1].values

# %%
#Splitting the data set into Training and testing set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=3)

# %%
#fitting the simple linear regression model to the training dataset
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction of Test and training set result
x_pred=reg.predict(x_train)
y_pred=reg.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,x_pred,color='red')
plt.title('Hours VS Marks (Training Dataset)')
plt.xlabel('Total hours studied by students')
plt.ylabel('Marks (in numbers)')
plt.show()

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_train,x_pred,color='red')
plt.title('Hours VS Marks (Training Dataset)')
plt.xlabel('Total hours studied by students')
plt.ylabel('Marks (in numbers)')
plt.show()

# %%
#Prediction for all Test Data
y_predict=reg.predict(x_test)
y_predict.round()
# Out:
# array([60., 46., 74., 79., 70., 60., 55., 41., 65., 41.])

# %%
#performance Analysis
from sklearn.metrics import mean_squared_error,r2_score
rscore=r2_score(y_test,y_predict)
r=rscore*100
print(r)
print(round(r),'%')
# Out:
# 85.87554175256062
# 86 %
