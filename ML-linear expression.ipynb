# %% [markdown]
# Inpendent variable  input  years
#
#
# dependannt variable Out put salary

# %%
#Importing the Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the Dataset
salary=pd.read_csv('salary data.csv')
salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
# It will tell the statistics information about the dataset
salary.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# Segregate the dataset into independant Variable (x) and dependant variable (y)

# %%
x=salary.iloc[:,:-1].values
y=salary.iloc[:,1].values

# %%
#Splitting the data set into Training and testing set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=2)

# %%
#fitting the simple linear regression model to the training dataset
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction of Test and training set result
x_pred=reg.predict(x_train)
y_pred=reg.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,x_pred,color='red')
plt.title('Salary VS Experience(Training Dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary (in Rupees)')
plt.show()

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_train,x_pred,color='red')
plt.title('Salary VS Experience(Training Dataset)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary (in Rupees)')
plt.show()

# %%
#Prediction for all Test Data
y_predict=reg.predict(x_test)
y_predict.round()
# Out:
# array([ 36075.,  34172.,  66516.,  58906.,  91250.,  80785., 101714.,
#         52247.,  42734.,  88396.])

# %%
#performance Analysis
from sklearn.metrics import mean_squared_error,r2_score
rscore=r2_score(y_test,y_predict)
r=rscore*100
print(r)
print(round(r),'%')
# Out:
# 90.41801644162628
# 90 %
